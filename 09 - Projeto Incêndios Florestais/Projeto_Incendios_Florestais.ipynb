# %% [markdown]
# Análise de Dados
#
# # **Incêndios Florestais no Brasil de 1998 a 2017** <p>
# Os incêndios florestais são um grave problema para a preservação das Florestas Tropicais. Compreender a frequência de incêndios florestais em uma série temporal pode ajudar a tomar medidas para evitá-los.
# O Brasil tem a maior floresta tropical do planeta que é a floresta amazônica.
#
# ![Captura de tela 2024-11-12 112232.png](data:image/png;base64,...)

# %%
# Libs para Modelagem e Matrizez
import numpy as np
import pandas as pd

# Libs para anaálises gráficas
import matplotlib.pyplot as plt
import seaborn as sns

# Lib para ignorar avisos
import warnings

# Desabilitando avisos
warnings.filterwarnings('ignore')

# %%
# Carregando Base de Dados
Base_Dados = pd.read_csv('Dados_Indendio.csv',encoding=('latin-1'))

# Verificando base de dados
Base_Dados.head(10)
# Out:
#    year state    month  number        date
# 0  1998  Acre  Janeiro     0.0  1998-01-01
# 1  1999  Acre  Janeiro     0.0  1999-01-01
# 2  2000  Acre  Janeiro     0.0  2000-01-01
# 3  2001  Acre  Janeiro     0.0  2001-01-01
# 4  2002  Acre  Janeiro     0.0  2002-01-01
# 5  2003  Acre  Janeiro    10.0  2003-01-01
# 6  2004  Acre  Janeiro     0.0  2004-01-01
# 7  2005  Acre  Janeiro    12.0  2005-01-01
# 8  2006  Acre  Janeiro     4.0  2006-01-01
# 9  2007  Acre  Janeiro     0.0  2007-01-01

# %%
Base_Dados.isnull().sum()
# Out:
# year      0
# state     0
# month     0
# number    0
# date      0
# dtype: int64

# %%
# Gráfico de campos nulos
plt.figure(figsize=(14,5))
plt.title('Análise de campos nulos')
sns.heatmap(Base_Dados.isnull(),cbar=False);

# %%
# Estatística
Base_Dados.describe()
# Out:
#               year       number
# count  6454.000000  6454.000000
# mean   2007.461729   108.293163
# std       5.746654   190.812242
# min    1998.000000     0.000000
# 25%    2002.000000     3.000000
# 50%    2007.000000    24.000000
# 75%    2012.000000   113.000000
# max    2017.000000   998.000000

# %%
Base_Dados.shape
# Out:
# (6454, 5)

# %%
Base_Dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6454 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    6454 non-null   int64
#  1   state   6454 non-null   object
#  2   month   6454 non-null   object
#  3   number  6454 non-null   float64
#  4   date    6454 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 252.2+ KB

# %%
# Campos unicos
Base_Dados.nunique()
# Out:
# year        20
# state       23
# month       12
# number    1479
# date        20
# dtype: int64

# %%
# Análise por ano dos incêndios
Analise = Base_Dados.groupby(by=['year'])['number'].sum().reset_index()

# Estilo
plt.style.use('ggplot')

# Tamanho
plt.figure(figsize=(14,5))

# Gráfico
plt.title('Total de Incêndios no Brasil: 1998 - 2017', loc='left', fontsize = 14)
sns.lineplot(data=Analise, x='year', y='number', estimator='sum', lw=2, color='#ff5555', alpha=0.85);

# Labels
plt.xlabel('Período')
plt.ylabel('Total de Incêndios');

# %%
# Analise por ano/mes de numero de incendios
Analise_02 = Base_Dados.groupby(by=['year','month']).sum().reset_index()

# Tamanho
plt.figure(figsize=(14,5))

# Gráfico
sns.boxplot(data = Analise_02, x='month', y='number', palette='viridis', width=0.9, linewidth=2,
            order=['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro'])
plt.title('Número de Incêndios por Mês', loc='left',fontsize=14)

# Labels
plt.xlabel('Mês')
plt.ylabel('Número de Incêndios');

# %%
# Analise estado por número de incêndios
Analise_03 = Base_Dados.groupby(by=['state'])['number'].sum().reset_index().sort_values(by='number', ascending=False)

# Tamanho
plt.figure( figsize=(12, 5) )

# Grafico
plt.title( 'Estados com maior número de incêndios', loc='left', fontsize=14 )

# Grafico
plt.bar( Analise_03.state, Analise_03['number'], color='#f44e3f' )

# Labels
plt.ylabel('Quantidade')
plt.xticks( rotation=90 );

# %%
# Estados TOP 05
Lista_TOP05 = Analise_03['state'][0:5].values

# Tamanho
plt.figure( figsize=(12, 5) )

# Grafico
plt.title( 'Top 05 Estados com Maior Índice de Incêndios', loc='left', fontsize=14 )

# Loop
for Coluna in Lista_TOP05:

  # Filtrar o estado
  Filtro = Base_Dados.loc[ Base_Dados['state'] == Coluna ]

  # Agrupar os valores para sumarizar
  Analise_Local = Filtro.groupby( by=['year'] ).sum().reset_index()

  # Plot
  sns.lineplot(data=Analise_Local, x='year', y='number', lw=2, alpha=0.85)

# Labels
plt.xlabel('Período')
plt.ylabel('Número de incêndios')

# Legenda
plt.legend( Lista_TOP05, bbox_to_anchor=(1, 0.7) );

# %%
# Plot Geográfico

# Gerando os estados
Estados = Analise_03.sort_values('state')['state'].values

# Gerando os valores
Valores = Analise_03.sort_values('state')['number'].values

# Latitudes
Lat = [ -8.77, -9.71,	1.41, -3.07,	-12.96, -3.71, -15.83, -19.19, -16.64, -2.55,	-12.64,
       -18.10, -7.06, -5.53, -8.28, -8.28,	-22.84,	-11.22,	1.89,	-27.33,	-23.55,	-10.90,	-10.25 ]

# Longitudes
Log = [ -70.55,	-35.73,	-51.77,	-61.66,	-38.51,	-38.54,	-47.86,	-40.34,	-49.31,	-44.30,	-55.42,	-44.38,
       -35.55,	-52.29,	-35.07,	-43.68,	-43.15,	-62.80,	-61.22,	-49.44,	-46.64,	-37.07,	-48.25 ]

# Organizados os dados
Dicionario = {
    'Estados' : Estados,
    'Latitude' : Lat,
    'Longitude' : Log,
    'Incêndios' : Valores
}

# Lendo o dicionario
Analise_Geografica = pd.DataFrame ( Dicionario )

Analise_Geografica.head()
# Out:
#     Estados  Latitude  Longitude  Incêndios
# 0      Acre     -8.77     -70.55  18464.030
# 1   Alagoas     -9.71     -35.73   4644.000
# 2     Amapa      1.41     -51.77  21831.576
# 3  Amazonas     -3.07     -61.66  30650.129
# 4     Bahia    -12.96     -38.51  44746.226

# %%
# Fazendo o plot
import plotly.express as px

# Mapa de Calor Geográfico
fig = px.density_mapbox(
    Analise_Geografica,
    lat='Latitude',
    lon='Longitude',
    z='Incêndios',
    radius=30,
    center=dict(lat=-12.700, lon=-46.5555),
    zoom=3,
    mapbox_style='open-street-map'
)

# Exibindo o mapa
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ![newplot (1).png](data:image/png;base64,...)

# %% [markdown]
# #### Podemos verificar através dos gráficos gerados acima, que praticamente todos os estados apresentaram incêndios nesse período, porém devemos ter uma atenção maior ao estado de Mato Grosso que desde 2001 vem apresentando o maior número de incêndios se comparado aos outros estados do Brasil.
#
# #### Verificamos também que os incêndios acontecem mais a partir do 2º semestre tendo a maior quantidade no mês de Agosto.
